# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Inclass - Lab<br> (Day 2)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Table of Content
# 1. **[Data Structures with Examples](#Data_Structures)**
# 2. **[Create and Manipulate the DataFrames](#create_manipulate)**
# 3. **[Sort](#sorting)**
# 4. **[Rank](#ranking)**

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='Data_Structures'></a>
# ## 1. Data Structures with Examples:

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Write a program to create a dataframe from list of lists
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below nested list:**<br>
#
#         data = [['Joy', 21], ['Mia', 15], ['Sam', 14]]

# %%
import pandas as pd
import numpy as np

# %%
# type your code here
data = [['Joy', 21], ['Mia', 15], ['Sam', 14]]
d=pd.DataFrame(data)
d
# Out:
#      0   1
# 0  Joy  21
# 1  Mia  15
# 2  Sam  14

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Extract the second word from the given string
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below string:**<br>
#
#     sentence = 'Be confident and be yourself'

# %%
# type your code here
sentence = 'Be confident and be yourself'
sentence[3:12]
# Out:
# 'confident'

# %% [markdown]
# <a id='create_manipulate'></a>
# ## 2. Create and Manipulate the DataFrames:

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Split the 'Name' column into two separate columns as First_Name and Last_Name </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>3200</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>4500</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>3600</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>5596</td>
# </tr>
#
# </table>

# %%
# type your code here
d={"Name":['Emma Larter' ,'Mia Junior' ,'Sophia Depp','James Smith'],
    "Salary":[3200,4500,3600,5596]}
d1=pd.DataFrame(d)
d1[['First_name','Last_name']]=d1.Name.str.split(expand=True)
d1
# Out:
#           Name  Salary First_name Last_name
# 0  Emma Larter    3200       Emma    Larter
# 1   Mia Junior    4500        Mia    Junior
# 2  Sophia Depp    3600     Sophia      Depp
# 3  James Smith    5596      James     Smith

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Select the rows from below dataframe where marks are less than 60 </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Marks</th>
# </tr>
# <tr>
# <td>John</td>
# <td>90</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>50</td>
# </tr>
# <tr>
# <td>Jonny</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>55</td>
# </tr>
#
# </table>

# %%
# type your code here

d1={"Name":['John','Robert','Jonny','Mia'],
    "Marks":[90,50,89,55]}
d=pd.DataFrame(d1)
d[d.Marks < 60]
# Out:
#      Name  Marks
# 1  Robert     50
# 3     Mia     55

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Write a program to select the rows where the sales are higher than 60000 for Mumbai </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here


d={"Store":['A','B','A','C','D','A','D','A','C','B'],
  "Location":['Mumbia','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
  "Sales":[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}

d1=pd.DataFrame(d)

d1[(d1.Sales >60000)  & (d1.Location=='Mumbai')]
# Out:
#   Store Location  Sales
# 3     C   Mumbai  90000
# 8     C   Mumbai  89000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Write a program to select stores located in Hyderabad</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
d={"Store":['A','B','A','C','D','A','D','A','C','B'],
  "Location":['Mumbia','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
  "Sales":[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}

d1=pd.DataFrame(d)
d1[d1.Location=='Hyderabad']['Store']
# Out:
# 2    A
# 6    D
# Name: Store, dtype: object

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Write a program to replace the 'Store' column with the values A, B, C, and D with Store_A,  Store_B, Store_C and Store_D respectively </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
d={"Store":['A','B','A','C','D','A','D','A','C','B'],
  "Location":['Mumbia','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
  "Sales":[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}

d1=pd.DataFrame(d)
ds={'A':'Store_A','B':'Store_B','A':'Store_A','C':'Store_C','D':'Store_D','A':'Store_A','D':'Store_D','A':'Store_A','C':'Store_C','B':'Store_B'}
d1['store']=d1.Store.map(ds)
d1
# Out:
#   Store   Location  Sales    store
# 0     A     Mumbia  40000  Store_A
# 1     B       Pune  45000  Store_B
# 2     A  Hyderabad  50000  Store_A
# 3     C     Mumbai  90000  Store_C
# 4     D       Pune  89000  Store_D
# 5     A      Delhi  87000  Store_A
# 6     D  Hyderabad  85000  Store_D
# 7     A       Pune  78000  Store_A
# 8     C     Mumbai  89000  Store_C
# 9     B       Pune  70000  Store_B

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Create a dataframe in pandas using the given list.
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below list**
#
#         city = ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']

# %%
# type your code here
city = ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']
pd.DataFrame(city)
# Out:
#          0
# 0    Delhi
# 1   Mumbai
# 2  Chennai
# 3  Kolkata

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Save a given dataframe to a csv file
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
d={"Store":['A','B','A','C','D','A','D','A','C','B'],
  "Location":['Mumbia','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
  "Sales":[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
d1=pd.DataFrame(d)
d1.to_csv('file.csv')

# %%
file=pd.read_csv('file.csv')
file
# Out:
#    Unnamed: 0 Store   Location  Sales
# 0           0     A     Mumbia  40000
# 1           1     B       Pune  45000
# 2           2     A  Hyderabad  50000
# 3           3     C     Mumbai  90000
# 4           4     D       Pune  89000
# 5           5     A      Delhi  87000
# 6           6     D  Hyderabad  85000
# 7           7     A       Pune  78000
# 8           8     C     Mumbai  89000
# 9           9     B       Pune  70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the maximum sales for each store
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
d={"Store":['A','B','A','C','D','A','D','A','C','B'],
  "Location":['Mumbia','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
  "Sales":[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
d1=pd.DataFrame(d)
d1.groupby(by='Store')['Sales'].max()
# Out:
# Store
# A    87000
# B    70000
# C    90000
# D    89000
# Name: Sales, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Write a program to select all columns, except the 'Location' from the given dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
d={"Store":['A','B','A','C','D','A','D','A','C','B'],
  "Location":['Mumbia','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
  "Sales":[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
d1=pd.DataFrame(d)
d1.iloc[:,[0,2]]
# Out:
#   Store  Sales
# 0     A  40000
# 1     B  45000
# 2     A  50000
# 3     C  90000
# 4     D  89000
# 5     A  87000
# 6     D  85000
# 7     A  78000
# 8     C  89000
# 9     B  70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Write a program to insert a given column at the second position in a dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Age</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>34</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>59</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>32</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>40</td>
# </tr>
#
# </table>
#
# **Add the variable 'Salary' as second column**<br>
#
#             Salary = [35000, 24000, 55000, 40000]

# %%
# type your code here
d1={"Name ":['Emma Larter' ,'Mia Junior' ,'Sophia Depp','James Smith'],
    "Age":[34,59,32,40]}
d=pd.DataFrame(d1)
Salary=[35000,24000,55000,40000]
d['Salary']=Salary
d
# Out:
#          Name   Age  Salary
# 0  Emma Larter   34   35000
# 1   Mia Junior   59   24000
# 2  Sophia Depp   32   55000
# 3  James Smith   40   40000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Write a program to get the third observation of the given dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Age</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>34</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>59</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>32</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>40</td>
# </tr>
# </table>

# %%
# type your code here
d1={"Name ":['Emma Larter' ,'Mia Junior' ,'Sophia Depp','James Smith'],
    "Age":[34,59,32,40]}
d=pd.DataFrame(d1)
d.iloc[2]
# Out:
# Name     Sophia Depp
# Age               32
# Name: 2, dtype: object

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Write a program to create a dataframe from the provided lists</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the following lists to create your arrays:**
#
#             columns = ["Science", "Maths", "English"]
#
#             marks = [[55, 78, 88], [93, 63, 83],[94, 74, 64]]
#
# **Hint:** Convert the list marks into an array

# %%
# type your code here
marks=[[55, 78, 88], [93, 63, 83],[94, 74, 64]]
columns = ["Science", "Maths", "English"]
m=np.array('marks')
d1=pd.DataFrame(marks,columns=columns)
d1
# Out:
#    Science  Maths  English
# 0       55     78       88
# 1       93     63       83
# 2       94     74       64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Write a program to count total sales per store </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
d={"Store":['A','B','A','C','D','A','D','A','C','B'],
  "Location":['Mumbia','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
  "Sales":[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}

d1=pd.DataFrame(d)
d1.groupby(by='Store')['Sales'].sum()
# Out:
# Store
# A    255000
# B    115000
# C    179000
# D    174000
# Name: Sales, dtype: int64

# %% [markdown]
# <a id='sorting'></a>
# ## 3. Sort

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Write a program to sort the dataframe by 'Sales' in ascending order
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
d={"Store":['A','B','A','C','D','A','D','A','C','B'],
  "Location":['Mumbia','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
  "Sales":[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}

d1=pd.DataFrame(d)
d1.sort_values(by='Sales',ascending=True)
# Out:
#   Store   Location  Sales
# 0     A     Mumbia  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 9     B       Pune  70000
# 7     A       Pune  78000
# 6     D  Hyderabad  85000
# 5     A      Delhi  87000
# 4     D       Pune  89000
# 8     C     Mumbai  89000
# 3     C     Mumbai  90000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Write a program to sort the dataframe by 'Store' in ascending order and by 'Sales' in descending order with respect to store simultaneously
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
d={"Store":['A','B','A','C','D','A','D','A','C','B'],
  "Location":['Mumbia','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
  "Sales":[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
d1=pd.DataFrame(d)
d1.sort_values(by=['Store','Sales'],ascending=[True,False])
# Out:
#   Store   Location  Sales
# 5     A      Delhi  87000
# 7     A       Pune  78000
# 2     A  Hyderabad  50000
# 0     A     Mumbia  40000
# 9     B       Pune  70000
# 1     B       Pune  45000
# 3     C     Mumbai  90000
# 8     C     Mumbai  89000
# 4     D       Pune  89000
# 6     D  Hyderabad  85000

# %% [markdown]
# <a id='ranking'></a>
# ## 4. Rank

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Create a column 'Rank_sales' which contains the rank of each store based on sales of the product in ascending order
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
d={"Store":['A','B','A','C','D','A','D','A','C','B'],
  "Location":['Mumbia','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
  "Sales":[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
d1=pd.DataFrame(d)
d1
# Out:
#   Store   Location  Sales
# 0     A     Mumbia  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
d1['Rank_sales']=d1['Sales'].rank(ascending=True)
d1
# Out:
#   Store   Location  Sales  Rank_sales
# 0     A     Mumbia  40000         1.0
# 1     B       Pune  45000         2.0
# 2     A  Hyderabad  50000         3.0
# 3     C     Mumbai  90000        10.0
# 4     D       Pune  89000         8.5
# 5     A      Delhi  87000         7.0
# 6     D  Hyderabad  85000         6.0
# 7     A       Pune  78000         5.0
# 8     C     Mumbai  89000         8.5
# 9     B       Pune  70000         4.0
